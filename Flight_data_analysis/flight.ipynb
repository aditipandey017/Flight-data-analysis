# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df1=pd.read_excel('FlightSchedule.xlsx')
df1.head(20)
# Out:
#    airline flightNumber     origin destination  \
# 0    GoAir          425      Delhi   Hyderabad
# 1    GoAir          423      Delhi   Hyderabad
# 2    GoAir          423      Delhi   Hyderabad
# 3    GoAir          423      Delhi   Hyderabad
# 4    GoAir          423      Delhi   Hyderabad
# 5    GoAir          423      Delhi   Hyderabad
# 6    GoAir          423      Delhi   Hyderabad
# 7    GoAir          422      Delhi   Hyderabad
# 8    GoAir          559    Lucknow   Hyderabad
# 9    GoAir          580      Kochi   Hyderabad
# 10   GoAir          587      Kochi   Hyderabad
# 11   GoAir          587      Kochi   Hyderabad
# 12   GoAir          553  Ahmedabad   Hyderabad
# 13   GoAir          552  Ahmedabad   Hyderabad
# 14   GoAir          553  Ahmedabad   Hyderabad
# 15   GoAir          552  Ahmedabad   Hyderabad
# 16   GoAir          701     Jaipur   Hyderabad
# 17   GoAir          431     Jaipur   Hyderabad
# 18   GoAir          385     Jaipur   Hyderabad
# ...

# %%
df1
# Out:
#         airline flightNumber     origin     destination  \
# 0         GoAir          425      Delhi       Hyderabad
# 1         GoAir          423      Delhi       Hyderabad
# 2         GoAir          423      Delhi       Hyderabad
# 3         GoAir          423      Delhi       Hyderabad
# 4         GoAir          423      Delhi       Hyderabad
# ...         ...          ...        ...             ...
# 88977  SpiceJet         2923  Hyderabad  Shirdi Airport
# 88978  SpiceJet         2923   Tirupati  Shirdi Airport
# 88979  SpiceJet          329    Chennai  Shirdi Airport
# 88980  SpiceJet         2950      Delhi          Kangra
# 88981  SpiceJet         2345      Delhi          Kangra
#
#                                               daysOfWeek  \
# 0      Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...
# 1                                               Saturday
# 2                                                 Friday
# 3                                                 Friday
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88982 entries, 0 to 88981
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 88307 non-null  object
#  1   flightNumber            88659 non-null  object
#  2   origin                  88482 non-null  object
#  3   destination             88435 non-null  object
#  4   daysOfWeek              88981 non-null  object
#  5   scheduledDepartureTime  58296 non-null  object
#  6   scheduledArrivalTime    58014 non-null  object
#  7   timezone                88982 non-null  datetime64[ns]
#  8   validFrom               88982 non-null  datetime64[ns]
#  9   validTo                 88982 non-null  datetime64[ns]
#  10  lastUpdated             88982 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), object(7)
# memory usage: 7.5+ MB

# %%
df1.isnull().sum() #use drop na to drop null values
# Out:
# airline                     675
# flightNumber                323
# origin                      500
# destination                 547
# daysOfWeek                    1
# scheduledDepartureTime    30686
# scheduledArrivalTime      30968
# timezone                      0
# validFrom                     0
# validTo                       0
# lastUpdated                   0
# dtype: int64

# %%
df=df1.dropna()
df
# Out:
#          airline flightNumber     origin destination  \
# 8          GoAir          559    Lucknow   Hyderabad
# 9          GoAir          580      Kochi   Hyderabad
# 10         GoAir          587      Kochi   Hyderabad
# 11         GoAir          587      Kochi   Hyderabad
# 12         GoAir          553  Ahmedabad   Hyderabad
# ...          ...          ...        ...         ...
# 59332  Akasa Air         1324   Agartala    Guwahati
# 59335  Akasa Air         1115     Mumbai     Chennai
# 59336  Akasa Air         1304     Mumbai     Chennai
# 59338  Akasa Air         1327  Bengaluru     Chennai
# 59340  Akasa Air         1323   Guwahati    Agartala
#
#                                               daysOfWeek  \
# 8      Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday
# 9      Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...
# 10     Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday
# 11                                                Monday
# ...

# %%
cols_to_drop = ['lastUpdated']
df.drop(columns=cols_to_drop, inplace=True)
df.head()
# Out:
# C:\Users\aditi\AppData\Local\Temp\ipykernel_27664\3607194401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=cols_to_drop, inplace=True)
#    airline flightNumber     origin destination  \
# 8    GoAir          559    Lucknow   Hyderabad
# 9    GoAir          580      Kochi   Hyderabad
# 10   GoAir          587      Kochi   Hyderabad
# 11   GoAir          587      Kochi   Hyderabad
# 12   GoAir          553  Ahmedabad   Hyderabad
#
#                                            daysOfWeek scheduledDepartureTime  \
# 8   Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday               15:45:00
# 9   Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...               04:45:00
# 10  Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday               17:20:00
# ...

# %%
df.isnull().sum()
# Out:
# airline                   0
# flightNumber              0
# origin                    0
# destination               0
# daysOfWeek                0
# scheduledDepartureTime    0
# scheduledArrivalTime      0
# timezone                  0
# validFrom                 0
# validTo                   0
# dtype: int64

# %%
print('columns with numeric data')
print(df.select_dtypes(include='number').columns.tolist())
print('columns with non numerica data')
print(df.select_dtypes(exclude='number').columns.tolist())
# Out:
# columns with numeric data
# []
# columns with non numerica data
# ['airline', 'flightNumber', 'origin', 'destination', 'daysOfWeek', 'scheduledDepartureTime', 'scheduledArrivalTime', 'timezone', 'validFrom', 'validTo']

# %%
df1.describe()
# Out:
#                             timezone                      validFrom  \
# count                          88982                          88982
# mean   2021-08-08 15:48:06.974893568  2021-04-04 07:33:38.592524544
# min              2018-10-28 00:00:00            2018-10-28 00:00:00
# 25%              2020-04-30 00:00:00            2020-03-29 00:00:00
# 50%              2021-10-29 00:00:00            2021-05-01 00:00:00
# 75%              2022-10-29 00:00:00            2022-03-28 00:00:00
# max              2023-10-28 00:00:00            2023-10-28 00:00:00
#
#                              validTo          lastUpdated
# count                          88982                88982
# mean   2021-08-08 15:48:06.974893568  2023-10-03 00:00:00
# min              2018-10-28 00:00:00  2023-10-03 00:00:00
# 25%              2020-04-30 00:00:00  2023-10-03 00:00:00
# 50%              2021-10-29 00:00:00  2023-10-03 00:00:00
# 75%              2022-10-29 00:00:00  2023-10-03 00:00:00
# ...

# %%
df.describe()
# Out:
#                             timezone                      validFrom  \
# count                          27054                          27054
# mean   2021-07-03 22:16:18.842315264  2021-01-31 00:24:19.481038080
# min              2018-10-28 00:00:00            2018-10-28 00:00:00
# 25%              2020-03-28 00:00:00            2019-10-27 00:00:00
# 50%              2021-04-30 00:00:00            2021-03-28 00:00:00
# 75%              2022-10-29 00:00:00            2022-03-27 00:00:00
# max              2023-10-28 00:00:00            2023-10-28 00:00:00
#
#                              validTo
# count                          27054
# mean   2021-07-03 22:16:18.842315264
# min              2018-10-28 00:00:00
# 25%              2020-03-28 00:00:00
# 50%              2021-04-30 00:00:00
# 75%              2022-10-29 00:00:00
# max              2023-10-28 00:00:00

# %%
# df.dtype()

# %%
rename_dict = {'airline':'Airline',
                'scheduledDepartureTime':'DepartureTime',
                'scheduledArrivalTime':'ArrivalTime',
                'timezone':'Date'}
df.rename(columns=rename_dict, inplace=True)
df.head()
# Out:
# C:\Users\aditi\AppData\Local\Temp\ipykernel_27664\391159477.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=rename_dict, inplace=True)
#    Airline flightNumber     origin destination  \
# 8    GoAir          559    Lucknow   Hyderabad
# 9    GoAir          580      Kochi   Hyderabad
# 10   GoAir          587      Kochi   Hyderabad
# 11   GoAir          587      Kochi   Hyderabad
# 12   GoAir          553  Ahmedabad   Hyderabad
#
#                                            daysOfWeek DepartureTime  \
# 8   Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday      15:45:00
# 9   Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...      04:45:00
# 10  Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday      17:20:00
# ...

# %%
df.set_index('Airline', inplace=True)
df.head()
# Out:
#         flightNumber     origin destination  \
# Airline
# GoAir            559    Lucknow   Hyderabad
# GoAir            580      Kochi   Hyderabad
# GoAir            587      Kochi   Hyderabad
# GoAir            587      Kochi   Hyderabad
# GoAir            553  Ahmedabad   Hyderabad
#
#                                                 daysOfWeek DepartureTime  \
# Airline
# GoAir    Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday      15:45:00
# GoAir    Sunday,Monday,Tuesday,Wednesday,Thursday,Frida...      04:45:00
# GoAir    Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday      17:20:00
# GoAir                                               Monday      17:50:00
# GoAir      Sunday,Monday,Tuesday,Wednesday,Thursday,Friday      11:05:00
#
#         ArrivalTime       Date  validFrom    validTo
# Airline
# GoAir      17:45:00 2019-03-30 2018-10-28 2019-03-30
# GoAir      06:15:00 2019-03-30 2018-10-28 2019-03-30
# GoAir      19:20:00 2019-03-30 2018-10-28 2019-03-30
# ...

# %%
(df.origin +' '+df.destination).value_counts().head(25).plot(kind='bar')
# Out:
# <Axes: >

# %%
(df.origin +' '+df.destination).value_counts().head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
px.sunburst(
    data_frame=df,
    path=['origin','destination'],
    values='flightNumber',
    names=df.index,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2368, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "5376Z"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\aditi\miniconda3\Lib\site-packages\plotly\express\_core.py:1647, in process_dataframe_hierarchy(args)
#    1646 try:
# -> 1647     df[args["values"]] = pd.to_numeric(df[args["values"]])
#    1648 except ValueError:
#
# File c:\Users\aditi\miniconda3\Lib\site-packages\pandas\core\tools\numeric.py:222, in to_numeric(arg, errors, downcast, dtype_backend)
#     221 try:
# --> 222     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223         values,
#     224         set(),
# ...

# %%
''' total= list(range(1980,2014))
df['Total'] = df[total].sum(axis=1)
df.head()'''
# Out:
# " total= list(range(1980,2014))\ndf['Total'] = df[total].sum(axis=1)\ndf.head()"

# %%
''' df.loc['GoAir', flightNumber].plot(figsize=(15,5), title= "GoAir Flight Details", style='ro--')'''
# Out:
# ' df.loc[\'GoAir\', flightNumber].plot(figsize=(15,5), title= "GoAir Flight Details", style=\'ro--\')'

# %%
#Cleaning and Formatting data
'''df['DepTime'] = df.DepTime[~df.DepTime.isna()].astype(np.int64).apply('{:0>4}'.format)
df['DepTime'] = pd.to_timedelta(df.DepTime.str[:2]+':'+df.DepTime.str[2:]+':00')

df['CRSDepTime'] = df.CRSDepTime[~df.CRSDepTime.isna()].astype(np.int64).apply('{:0>4}'.format)
df['CRSDepTime'] = pd.to_timedelta(df.CRSDepTime.str[:2]+':'+df.CRSDepTime.str[2:]+':00')

df['ArrTime'] = df.ArrTime[~df.ArrTime.isna()].astype(np.int64).apply('{:0>4}'.format)
df['ArrTime'] = pd.to_timedelta(df.ArrTime.str[:2]+':'+df.ArrTime.str[2:]+':00')

df['CRSArrTime'] = df.CRSArrTime[~df.CRSArrTime.isna()].astype(np.int64).apply('{:0>4}'.format)
df['CRSArrTime'] = pd.to_timedelta(df.CRSArrTime.str[:2]+':'+df.CRSArrTime.str[2:]+':00')

# df[['DepTime','CRSDepTime', 'ArrTime', 'CRSArrTime']] = df[['DepTime','CRSDepTime', 'ArrTime', 'CRSArrTime']].apply(lambda x: pd.to_timedelta(x))
'''
